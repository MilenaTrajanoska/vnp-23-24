# %% [markdown]
# # Web Scraping with BeautifulSoup in Python

# %% [markdown]
# Import the required libraries
#
# BeautifulSoup documentation: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Pandas documentation: https://pandas.pydata.org/docs/getting_started/intro_tutorials/01_table_oriented.html

# %% [markdown]
# **First click on the icon to connect Google Drive, the third one in the side menu. We need the connection to save the data in the end**

# %%
import requests
from IPython.display import display, HTML
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# Define the start URL for scraping the page

# %%
base_url = "https://www.setec.mk/"

# %%
response = requests.get(base_url)

# %%
response  # If the response status code is 200 it means we have successfully got the page
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# Display the HTML, raw without styles

# %%
display(HTML(response.text))
# Out:
# <!DOCTYPE html> <html lang="mk" class="responsive"> <head> <title>Сетек | сè од техника</title> <meta property="og:image:width" content="1200"/> <meta property="og:image:height" content="630"/> <meta property="og:image:type" content="image/jpeg"/> <meta content="Сетек | сè од техника, Сетек се од техника" property="og:title"/> <meta content="product" property="og:type"/> <meta content="https://www.setec.mk/image/catalog/Promo/setec_logo_modal.jpg" property="og:image"/> <meta name="description" content="Сетек | Сè од техника" property="og:description"/> <meta name="keywords" content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in appliances, Small domestic appliances, Kitchen appliances, Personal and beauty care, Products for home use, Kitchen equipment, Heating and Cooling, Air Conditioners, Electric heaters, Cooling ventilators, Batteries, lamps, Преносни компјутери, Компјутери, ИТ опрема, Компјутерска опрема, Компјутерски Делови, ТВ, Телевизори, Аудио, Видео, Телефони, Навигација, Фотоапарати, Камери, Бела Техника, Мали Апарати, Ладење, Греење, Таблет Компјутери, Дополнителна опрема, Монитори, Конфигурации, Канцелариски мебел, ЛЕД, ЛЦД, Уреди, Мобилни, DSLR, Видео надзор, Фото, Машини за перење на алишта, Машини за сушење на алишта, Фрижидери, Вградна техника, Шпорети, Аспиратори, Бојлери, Кујнски апарати, Лична нега и убавина, Апарати за домаќинство, Кујнски прибор, Климатизери, Вентилатори, Греалки, СЕТЕК, сетек, сетец, сет, сет мк, сет ком мк, setec, setek, set, set mk, set com mk, set kom mk, set kompjuteri, setek kompjuteri, setec kompjuteri, сет компјутери, сетек компјутери, сетец компјутери, setexs, сетекс, seteks, setexs mk, сетекс мк, seteks mk, setexsmk, сетексмк, seteksmk,semtex, семтекс"/> <script src="https://ua.realtimely.io/script.js" data-site="SETEC" defer></script> <base href="https://setec.mk/"/> <meta charset="utf-8"/> <meta http-equiv="X-UA-Compatible" content="IE=edge"/> <meta name="viewport" content="width=device-width, initial-scale=1.0"/> <meta name="description" content="Сетек | сè од техника, Сетек се од техника"/> <meta name="keywords" content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in appliances, Small domestic appliances, Kitchen appliances, Personal and beauty care, Products for home use, Kitchen equipment, Heating and Cooling, Air Conditioners, Electric heaters, Cooling ventilators, Batteries, lamps, Преносни компјутери, Компјутери, ИТ опрема, Компјутерска опрема, Компјутерски Делови, ТВ, Телевизори, Аудио, Видео, Телефони, Навигација, Фотоапарати, Камери, Бела Техника, Мали Апарати, Ладење, Греење, Таблет Компјутери, Дополнителна опрема, Монитори, Конфигурации, Канцелариски мебел, ЛЕД, ЛЦД, Уреди, Мобилни, DSLR, Видео надзор, Фото, Машини за перење на алишта, Машини за сушење на алишта, Фрижидери, Вградна техника, Шпорети, Аспиратори, Бојлери, Кујнски апарати, Лична нега и убавина, Апарати за домаќинство, Кујнски прибор, Климатизери, Вентилатори, Греалки, СЕТЕК, сетек, сетец, сет, сет мк, сет ком мк, setec, setek, set, set mk, set com mk, set kom mk, set kompjuteri, setek kompjuteri, setec kompjuteri, сет компјутери, сетек компјутери, сетец компјутери, setexs, сетекс, seteks, setexs mk, сетекс мк, seteks mk, setexsmk, сетексмк, seteksmk,semtex, семтекс"/> <link href="https://setec.mk/image/catalog/favicon.png" rel="icon"/> <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=740699192966713&ev=PageView&noscript=1" /></noscript> <meta name="google-site-verification" content="LxaSU7Y_ucgR7c_hh6Ympnm15bl4Q8rcvKryJxma5wo"/> <link rel="stylesh ...

# %%
raw_html = response.text  # get the raw response, the response object also contains the status code, and other metadata

# %% [markdown]
# Parse the HTML using BeautifulSoup
#
# This creates an object which allows us to access html elements using tags, css selectiors and attribute values.

# %%
soup = BeautifulSoup(raw_html, "html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="responsive" lang="mk">
#  <head>
#   <title>
#    Сетек | сè од техника
#   </title>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="image/jpeg" property="og:image:type"/>
#   <meta content="Сетек | сè од техника, Сетек се од техника" property="og:title"/>
#   <meta content="product" property="og:type"/>
#   <meta content="https://www.setec.mk/image/catalog/Promo/setec_logo_modal.jpg" property="og:image"/>
#   <meta content="Сетек | Сè од техника" name="description" property="og:description"/>
#   <meta content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in appliances, Small domestic appliances, Kitchen appliances, Personal and beauty care, Products for home use, Kitchen equipment, Heating and Cooling, Air Conditioners, Electric heaters, Cooling ventilators, Batteries, lamps, Преносни компјутери, Компјутери, ИТ опрема, Компјутерска опрема, Компјутерски Делови, ТВ, Телевизори, Аудио, Видео, Телефони, Навигација, Фотоапарати, Камери, Бела Техника, Мали Апарати, Ладење, Греење, Таблет Компјутери, Дополнителна опрема, Монитори, Конфигурации, Канцелариски мебел, ЛЕД, ЛЦД, Уреди, Мобилни, DSLR, Видео надзор, Фото, Машини за перење на алишта, Машини за сушење на алишта, Фрижидери, Вградна техника, Шпорети, Аспиратори, Бојлери, Кујнски апарати, Лична нега и убавина, Апарати за домаќинство, Кујнски прибор, Климатизери, Вентилатори, Греалки, СЕТЕК, сетек, сетец, сет, сет мк, сет ком мк, setec, setek, set, set mk, set com mk, set kom mk, set kompjuteri, setek kompjuteri, setec kompjuteri, сет компјутери, сетек компјутери, сетец компјутери, setexs, сетекс, seteks, setexs mk, сетекс мк, seteks mk, setexsmk, сетексмк, seteksmk,semtex, семтекс" name="keywords"/>
#   <script data-site="SETEC" defer="" src="https://ua.realtimely.io/script.js">
#   </script>
#   <base href="https://setec.mk/"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="Сетек | сè од техника, Сетек се од техника" name="description"/>
#   <meta content="Laptops, Computers and IT, Notebooks, Tablets, Accessories, PC and equipment, Tv, Audio, Video, LED TV, LCD TV, Phones and Navigation, Mobile Phones and Accessories, White Goods, Washing, Dryers, Diswasher, Refrigerators, Freezers, Photo, Camera, Built in appliances, Small domestic appliances, Kitchen appliances, Personal and beauty care, Products for home use, Kitchen equipment, Heating and Cooling, Air Conditioners, Electric heaters, Cooling ventilators, Batteries, lamps, Преносни компјутери, Компјутери, ИТ опрема, Компјутерска опрема, Компјутерски Делови, ТВ, Телевизори, Аудио, Видео, Телефони, Навигација, Фотоапарати, Камери, Бела Техника, Мали Апарати, Ладење, Греење, Таблет Компјутери, Дополнителна опрема, Монитори, Конфигурации, Канцелариски мебел, ЛЕД, ЛЦД, Уреди, Мобилни, DSLR, Видео надзор, Фото, Машини за перење на алишта, Машини за сушење на алишта, Фрижидери, Вградна техника, Шпорети, Аспиратори, Бојлери, Кујнски апарати, Лична нега и убавина, Апарати за домаќинство, Кујнски прибор, Климатизери, Вентилатори, Греалки, СЕТЕК, сетек, сетец, сет, сет мк, сет ком мк, setec, setek, set, set mk, set com mk, set kom mk, set kompjuteri, setek kompjuteri, setec kompjuteri, сет компјутери, сетек компјутери, сетец компјутери, setexs, сетекс, seteks, setexs mk, сетекс мк, seteks mk, setexsmk, сетексмк, seteksmk,semtex, семтекс" name="keywords"/>
#   <link href="https://setec.mk/image/catalog/favicon.png" rel="icon"/>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=740699192966713&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <meta content="LxaSU7Y_ucgR7c_hh6Ympnm15bl4Q8rcvKryJxma5wo" name="google-site-verification"/>
#   <link href="//netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Poppins:300,400,500,600,700" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto:800,700,600,500,400,300,200,100" media="all" rel="stylesheet" type="text/css"/>
#   <link href="catalog/view/theme/assets/css/1-3d4372ca9bfcfee861dca646b335b054-0-nitro-combined-1572544626-2f69be9bf5a9847243c776b71a96df9e.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="catalog/view/theme/assets/css/1-3d4372ca9bfcfee861dca646b335b054-0-nitro-combined-1572544626-6fa34e11f04777672aca819ee535945b.css" media="screen" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="common-home product-list-type-4 product-grid-type-3 dropdown-menu-type-4 buttons-prev-next-type-2 cart-block-type-9 top-bar-type-4 product-page-type-2 megamenu-type-20 megamenu-label-type-2 no-box-type-7 box-type-19 button-body-type-15 countdown-special-type-9 footer-type-18 breadcrumb-style-3 border-width-0 body-other banners-effect-9 body-header-type-20">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PZHBZZX" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="popup mfp-hide" id="popup-1" style="max-width: 600px;background-image: url(image/catalog/Promo/600x600_SD_oct_2023.jpg);background-position: top center;background-repeat: no-repeat;">
#    <div class="content">
#    </div>
#   </div>
#   <div class="standard-body">
#    <div class="" id="main">
#     <div class="fixed-header-1 sticky-header">
#      <div class="background-header">
#      </div>
#      <div class="slider-header">
#       <div class="full-width" id="top">
#        <div class="background-top">
#        </div>
#        <div class="background">
#         <div class="shadow">
#         </div>
#         <div class="pattern">
#          <div class="megamenu-background">
#           <div class="">
#            <div class="overflow-megamenu container">
#             <div class="row mega-menu-modules">
#              <div class="col-md-3">
#               <div class="container-megamenu vertical" id="megamenu_54098670">
#                <div id="menuHeading">
#                 <div class="megamenuToogle-wrapper">
#                  <div class="megamenuToogle-pattern">
#                   <div class="container">
#                    СИТЕ КАТЕГОРИИ
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <div class="megamenu-wrapper">
#                 <div class="megamenu-pattern">
#                  <div class="container">
#                   <ul class="megamenu shift-left">
#                    <li class="home">
#                     <a href="https://setec.mk/index.php?route=common/home">
#                      <i class="fa fa-home">
#                      </i>
#                     </a>
#                    </li>
#                    <li class="with-sub-menu hover">
#                     <p class="close-menu">
#                     </p>
#                     <p class="open-menu">
#                     </p>
#                     <a class="clearfix" href="">
#                      <span>
#                       <strong>
#                        Компјутери и IT Опрема
#                       </strong>
#                      </span>
#                     </a>
#                     <div class="sub-menu" style="width:980px">
#                      <div class="content">
#                       <p class="arrow">
#                       </p>
#                       <div class="row">
#                        <div class="col-sm-4 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu with-submenu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10038" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10038';">
#                               Компјутерска галантерија
#                              </a>
#                              <div class="open-categories">
#                              </div>
#                              <div class="close-categories">
#                              </div>
#                              <ul>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10040" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10040';">
#                                 Тастатури
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10039" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10039';">
#                                 Глувци и Подлога за Глувци
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10042" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10042';">
#                                 Преносни кутии
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10041" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10038_10041';">
#                                 Веб Камери
#                                </a>
#                               </li>
#                              </ul>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10051" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10051';">
#                               Кабли/конектори/адаптери
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10052" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10052';">
#                               Алати
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10053" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10053';">
#                               Мултимедија
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10221" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10221';">
#                               Канцелариски мебел и опрема
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10223" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10223';">
#                               Разни компјутерски додатоци
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu with-submenu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10271" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10271';">
#                               Столици
#                              </a>
#                              <div class="open-categories">
#                              </div>
#                              <div class="close-categories">
#                              </div>
#                              <ul>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10271_10293" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10271_10293';">
#                                 GAMING столици
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10271_10294" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10271_10294';">
#                                 Оffice столици
#                                </a>
#                               </li>
#                              </ul>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="col-sm-4 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10031" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10031';">
#                               Монитори
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10032" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10032';">
#                               Конфигурации
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10033" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10033';">
#                               Печатари
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10035" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10035';">
#                               Скенери
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10036" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10036';">
#                               Потрошен материјал (Тонери, мастила и хартија)
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10037" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10037';">
#                               Мрежна опрема
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10043" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10043';">
#                               Слушалки, микрофони и звучници
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10044" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10044';">
#                               USB Мемории
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10045" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10045';">
#                               Мемориски Картички и читачи
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10046" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10046';">
#                               Софтвер
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10047" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10047';">
#                               Екстерни Дискови
#                              </a>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="col-sm-4 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu with-submenu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020';">
#                               Компјутери и Компјутерски Делови
#                              </a>
#                              <div class="open-categories">
#                              </div>
#                              <div class="close-categories">
#                              </div>
#                              <ul>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10028" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10028';">
#                                 Куќишта
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10027" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10027';">
#                                 Кулери
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10025" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10025';">
#                                 Графички Карти
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10023" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10023';">
#                                 Тврди Дискови и SSD Дискови
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10022" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10022';">
#                                 Матични Плочи
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10026" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10026';">
#                                 Оптички Уреди
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10029" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10029';">
#                                 Напојувања
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10021" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10021';">
#                                 Процесори
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10024" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10024';">
#                                 РАМ Меморија
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10030" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10020_10030';">
#                                 TV &amp; Звучни карти
#                                </a>
#                               </li>
#                              </ul>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10048" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10048';">
#                               Медии ( Празни Дискови CD/DVD/Blue Ray)
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10049" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10049';">
#                               Проектори
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10050" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10050';">
#                               UPS и Продолжни кабли
#                              </a>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </li>
#                    <li class="with-sub-menu hover">
#                     <p class="close-menu">
#                     </p>
#                     <p class="open-menu">
#                     </p>
#                     <a class="clearfix" href="">
#                      <span>
#                       <strong>
#                        Преносни Компјутери
#                       </strong>
#                      </span>
#                     </a>
#                     <div class="sub-menu" style="width:980px">
#                      <div class="content">
#                       <p class="arrow">
#                       </p>
#                       <div class="row">
#                        <div class="col-sm-5 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10003" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10003';">
#                               Преносни Компјутери
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu with-submenu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005';">
#                               Дополнителна опрема за Преносни Компјутери
#                              </a>
#                              <div class="open-categories">
#                              </div>
#                              <div class="close-categories">
#                              </div>
#                              <ul>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10009" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10009';">
#                                 Батерии
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10010" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10010';">
#                                 Средства за чистење на LCD/LED екрани
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10006" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10006';">
#                                 Ташни и Ранци
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10007" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10007';">
#                                 Ладилник (Cooler) со лежиште
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10011" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10011';">
#                                 Останато
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10008" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10005_10008';">
#                                 Адаптери за струја
#                                </a>
#                               </li>
#                              </ul>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="col-sm-4 mobile-enabled">
#                         <div class="html">
#                          <ul>
#                           <li class="item" style="float: left; outline-style: solid !important; outline-color: #e8e8e8 !important; margin: 5px; line-height: 10px; outline-width: 1px !important; padding: 1px; list-style:none;">
#                            <a href="index.php?route=product/manufacturer/info&amp;manufacturer_id=19">
#                             <img src="/image/catalog/brands/Setec/Logo43.png" style="width: 90px; height: 48px;"/>
#                            </a>
#                           </li>
#                           <li class="item" style="float: left; outline-style: solid !important; outline-color: #e8e8e8 !important; margin: 5px; line-height: 10px; outline-width: 1px !important; padding: 2px;list-style:none;">
#                            <a href="index.php?route=product/manufacturer/info&amp;manufacturer_id=3">
#                             <img src="/image/catalog/brands/Setec/Logo50.png" style="width: 90px; height: 48px;"/>
#                            </a>
#                           </li>
#                           <li class="item" style="float: left; outline-style: solid !important; outline-color: #e8e8e8 !important; margin: 5px; line-height: 10px; outline-width: 1px !important; padding: 1px;list-style:none;">
#                            <a href="index.php?route=product/manufacturer/info&amp;manufacturer_id=61">
#                             <img src="/image/catalog/brands/Setec/Logo55.png" style="width: 90px; height: 48px;"/>
#                            </a>
#                           </li>
#                          </ul>
#                          <ul>
#                           <li class="item" style="float: left; outline-style: solid !important; outline-color: #e8e8e8 !important; margin: 5px; line-height: 10px; outline-width: 1px !important; padding: 2px;list-style:none;">
#                            <a href="index.php?route=product/manufacturer/info&amp;manufacturer_id=105">
#                             <img src="/image/catalog/brands/Setec/Logo56.png" style="width: 90px; height: 48px;"/>
#                            </a>
#                           </li>
#                           <li class="item" style="float: left; outline-style: solid !important; outline-color: #e8e8e8 !important; margin: 5px; line-height: 10px; outline-width: 1px !important; padding: 1px;list-style:none;">
#                            <a href="index.php?route=product/manufacturer/info&amp;manufacturer_id=128">
#                             <img src="/image/catalog/brands/Setec/Logo48.png" style="width: 90px; height: 48px;"/>
#                            </a>
#                           </li>
#                           <li class="item" style="float: left; outline-style: solid !important; outline-color: #e8e8e8 !important; margin: 5px; line-height: 10px; outline-width: 1px !important; padding: 2px;list-style:none;">
#                            <a href="index.php?route=product/manufacturer/info&amp;manufacturer_id=114">
#                             <img src="/image/catalog/brands/Setec/Logo38.png" style="width: 90px; height: 48px;"/>
#                            </a>
#                           </li>
#                          </ul>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </li>
#                    <li class="with-sub-menu hover">
#                     <p class="close-menu">
#                     </p>
#                     <p class="open-menu">
#                     </p>
#                     <a class="clearfix" href="">
#                      <span>
#                       <strong>
#                        Таблет Компјутери
#                       </strong>
#                      </span>
#                     </a>
#                     <div class="sub-menu" style="width:980px">
#                      <div class="content">
#                       <p class="arrow">
#                       </p>
#                       <div class="row">
#                        <div class="col-sm-2 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10004" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10004';">
#                               Таблети
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10015" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10015';">
#                               Адаптери
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10018" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10018';">
#                               Кабли
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10013" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10013';">
#                               Футроли за таблети
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10017" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10017';">
#                               Држачи
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10016" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10016';">
#                               Тастатури
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10014" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10002_10012_10014';">
#                               Заштитни фолии
#                              </a>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="col-sm-10 mobile-disabled">
#                         <img src="https://setec.mk/image/catalog/Meni/700x400-tableti.jpg" style="margin-top: -30px;margin-bottom:-37px;margin-left: 99px;"/>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </li>
#                    <li class="with-sub-menu hover">
#                     <p class="close-menu">
#                     </p>
#                     <p class="open-menu">
#                     </p>
#                     <a class="clearfix" href="">
#                      <span>
#                       <strong>
#                        Конзоли за играње
#                       </strong>
#                      </span>
#                     </a>
#                     <div class="sub-menu" style="width:350%">
#                      <div class="content">
#                       <p class="arrow">
#                       </p>
#                       <div class="row">
#                        <div class="col-sm-4 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu with-submenu" href="https://setec.mk/index.php?route=product/category&amp;path=10019_10190" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10190';">
#                               Конзоли за играње
#                              </a>
#                              <div class="open-categories">
#                              </div>
#                              <div class="close-categories">
#                              </div>
#                              <ul>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10190_10224" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10190_10224';">
#                                 Игри за Конзоли
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10190_10226" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10190_10226';">
#                                 Конзоли
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10190_30337" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10190_30337';">
#                                 Контролери и Волани
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10190_30339" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10190_30339';">
#                                 Дронови
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10019_10190_30340" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10019_10190_30340';">
#                                 Играчки
#                                </a>
#                               </li>
#                              </ul>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </li>
#                    <li class="with-sub-menu hover">
#                     <p class="close-menu">
#                     </p>
#                     <p class="open-menu">
#                     </p>
#                     <a class="clearfix" href="">
#                      <span>
#                       <strong>
#                        ТВ / Аудио / Видео
#                       </strong>
#                      </span>
#                     </a>
#                     <div class="sub-menu" style="width:980px">
#                      <div class="content">
#                       <p class="arrow">
#                       </p>
#                       <div class="row">
#                        <div class="col-sm-3 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu with-submenu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10055" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10055';">
#                               Телевизори
#                              </a>
#                              <div class="open-categories">
#                              </div>
#                              <div class="close-categories">
#                              </div>
#                              <ul>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10054_10055_10056" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10055_10056';">
#                                 LED Телевизори
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10054_10055_10258" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10055_10258';">
#                                 QLED Телевизори
#                                </a>
#                               </li>
#                               <li>
#                                <a href="https://setec.mk/index.php?route=product/category&amp;path=10054_10055_30334" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10055_30334';">
#                                 OLED Телевизори
#                                </a>
#                               </li>
#                              </ul>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10278" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10278';">
#                               Држачи за телевизори
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10059" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10059';">
#                               DVD/Blu Ray плеери
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10060" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10060';">
#                               Мултимедијални плеери
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10061" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10061';">
#                               DVD/Blu Ray домашни кина
#                              </a>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="col-sm-3 mobile-enabled">
#                         <div class="row">
#                          <div class="col-sm-12 static-menu">
#                           <div class="menu">
#                            <ul>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10062" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10062';">
#                               Hi Fi Аудио/Видео уреди за дома
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10063" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10063';">
#                               HI-FI Аудио уреди за во автомобил
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10064" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10064';">
#                               MP3/MP4 уреди
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10201" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10201';">
#                               ТВ Аксесоари
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10065" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10065';">
#                               SET Top Box и Антени
#                              </a>
#                             </li>
#                             <li>
#                              <a class="main-menu" href="https://setec.mk/index.php?route=product/category&amp;path=10054_10216" onclick="window.location = 'https://setec.mk/index.php?route=product/category&amp;path=10054_10216';">
#                               Диктафони
#                              </a>
#                             </li>
#                            </ul>
#                           </div>
#                          </div>
#                         </div>
#                        </div>
#                        <div class="col-sm-6 mobile-disabled">
#                         <img src="https://setec.mk/image/catalog/Meni/tv400x400.jpg" style="margin-top: -30px;margin-bottom:-37px;margin-left: 99px;"/>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </li>
#                    <li class="with-sub-menu hover">
#                     <p class="close-menu">
#                     </p>
#                     <p class="open-menu">
#                     </p>
#                     <a class="clearfix" href="">
#                      <span>
#                       <strong>
#                        Мобилни Телефони
#                       </strong>
#                      </span>
#                     </a>
#                     <div class="sub-menu" style="width:980px">
#                      <div class="content">
#                       <p class="arrow">
#                       </p>
#                       <div class="row">
# ...
#                   <a href="https://mojservis.mk/">
#                    Мој Сервис
#                   </a>
#                  </li>
#                  <li>
#                   <a href="https://setec.mk/index.php?route=information/information&amp;information_id=73">
#                    Информации за испорака
#                   </a>
#                  </li>
#                  <li>
#                   <a href="http://outlet.setec.mk">
#                    Оутлет Производи
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#              <div class="col-sm-3">
#               <h4>
#                Корисничка сметка
#               </h4>
#               <div class="strip-line">
#               </div>
#               <div class="row" style="clear: both">
#                <div class="col-sm-12">
#                 <ul>
#                  <li>
#                   <a href="index.php?route=account/login">
#                    Податоци за корисникот
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=account/order">
#                    Историја на нарачки
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=account/wishlist">
#                    Листа на желби
#                   </a>
#                  </li>
#                  <li>
#                   <a href="index.php?route=account/newsletter">
#                    Билтен
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#               </div>
#              </div>
#              <div class="col-sm-2">
#               <div class="row banners banners-with-padding-45">
#                <a href="https://setec.mk/samsung">
#                 <img alt="Banner" src="image/catalog/Promo/Samsung-esys.jpg"/>
#                </a>
#               </div>
#               <div class="row banners banners-with-padding-45">
#                <a href="https://setec.mk/apple">
#                 <img alt="Banner" src="image/catalog/Promo/Bellow_slider_link-to-SIS.png"/>
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="row">
#              <div class="col-sm-12">
#               <div class="text-center">
#                © 2022 Сетек Сè од Техника.
#                <ul class="social-icons-default" style="padding-top: 7px">
#                 <li>
#                  <a href="https://www.facebook.com/setec.com.mk">
#                   <i class="fa fa-facebook">
#                   </i>
#                  </a>
#                 </li>
#                 <li>
#                  <a href="https://www.youtube.com/user/SetecSeodTehnika/videos">
#                   <i class="fa fa-youtube-play">
#                   </i>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <a href="javascript:" id="return-to-top">
#    <i class="icon-chevron-up">
#    </i>
#   </a>
#   <script src="//www.googletagmanager.com/gtag/js?id=UA-44463679-1" type="text/javascript">
#   </script>
#   <script src="//www.googletagmanager.com/gtag/js?id=AW-858906868" type="text/javascript">
#   </script>
#   <script src="//www.googletagmanager.com/gtag/js?id=G-0X2WEV7GDL" type="text/javascript">
#   </script>
#   <script src="catalog/view/theme/assets/js/1-3d4372ca9bfcfee861dca646b335b054-0-nitro-combined-1572544619-9a7fd5e62f45c5d7ab3e58e84bec389d.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var responsive_design = 'yes';
#   </script>
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-44463679-1']);
#   _gaq.push(['_setDomainName', 'setec.mk']);
#   _gaq.push(['_setAllowLinker', true]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-44463679-1');
#   </script>
#   <script type="text/javascript">
#    !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '740699192966713');
#   fbq('track', 'PageView');
#   </script>
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'AW-858906868');
#   </script>
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-0X2WEV7GDL');
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
#
# if($(window).width() > 992) {
#
#
#           var show_after = parseInt('', 20);
#           var autoclose_after = parseInt('10000', 20);
#           setTimeout(function () {
#             $.magnificPopup.open({
#                 items: {
#                     src: '#popup-1',
#                     type: 'inline'
#                 },
#                 tLoading: '',
#                 mainClass: 'popup-module mfp-with-zoom popup-type-2',
#                 removalDelay: 200,
#                             });
#
#             if (autoclose_after > 0) {
#                 setTimeout(function () {
#                     $.magnificPopup.close();
#                 }, autoclose_after);
#             }
#           }, show_after);
#
#
#
# }
#
# });
#   </script>
#   <script type="text/javascript">
#    $(window).load(function(){
#       var css_tpl = '<style type="text/css">';
#       css_tpl += '#megamenu_54098670 ul.megamenu > li > .sub-menu > .content {';
#       css_tpl += '-webkit-transition: all 500ms ease-out !important;';
#       css_tpl += '-moz-transition: all 500ms ease-out !important;';
#       css_tpl += '-o-transition: all 500ms ease-out !important;';
#       css_tpl += '-ms-transition: all 500ms ease-out !important;';
#       css_tpl += 'transition: all 500ms ease-out !important;';
#       css_tpl += '}</style>'
#     $("head").append(css_tpl);
#   });
#   </script>
#   <script type="text/javascript">
#    $(window).load(function(){
#       var css_tpl = '<style type="text/css">';
#       css_tpl += '#megamenu_72847122 ul.megamenu > li > .sub-menu > .content {';
#       css_tpl += '-webkit-transition: all 200ms ease-out !important;';
#       css_tpl += '-moz-transition: all 200ms ease-out !important;';
#       css_tpl += '-o-transition: all 200ms ease-out !important;';
#       css_tpl += '-ms-transition: all 200ms ease-out !important;';
#       css_tpl += 'transition: all 200ms ease-out !important;';
#       css_tpl += '}</style>'
#     $("head").append(css_tpl);
#   });
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 							     			$('#search_query').autocomplete({
# 							     				delay: 0,
# 							     				appendTo: "#autocomplete-results",
# 							     				source: function(request, response) {
# 							     					$.ajax({
# 							     						url: 'index.php?route=search/autocomplete&filter_name=' +  encodeURIComponent(request.term),
# 							     						dataType: 'json',
# 							     						success: function(json) {
# 							     							response($.map(json, function(item) {
# 							     								return {
# 							     									label: item.name,
# 							     									value: item.product_id,
# 							     									href: item.href,
# 							     									thumb: item.thumb,
# 							     									desc: item.desc,
# 							     									price: item.price,
# 																	quantity: item.quantity,
# 																	special: item.special
# 							     								}
# 							     							}));
# 							     						}
# 							     					});
# 							     				},
# 							     				select: function(event, ui) {
# 							     					document.location.href = ui.item.href;
#
# 							     					return false;
# 							     				},
# 							     				focus: function(event, ui) {
# 							     			      	return false;
# 							     			   	},
# 							     			   	minLength: 2
# 							     			})
# 							     			.data( "ui-autocomplete" )._renderItem = function( ul, item ) {
# 							     			  return $( "<li>" )
# 			.append( "<a>" + "<img class='col-xs-3' src="+item.thumb+">" + "<p class='col-xs-9' style='top: 15px'>" + item.label + "</p>" + "<p class='col-xs-4' style='top: 15px; font-size: 15px; font-weight: 300;'>" + item.price + "</p>" + "<p class='col-xs-5' style='top: 15px; font-size: 18px; background-color: #fff2e2; text-align: center; color: red; font-weight: 300;'>" + item.special + "</p>" + "</a>" )
# 			.appendTo( ul );
# 							     			};
# 							     		});
#   </script>
#   <script type="text/javascript">
#    function remove_applied_wallet(){
#               $.ajax({
#                 url: 'index.php?route=extension/total/wallet/remove_applied_wallet',
#                 type: 'get',
#                 dataType: 'json',
#                 success: function(json) {
#                   if (json['redirect']) {
#                     location = json['redirect'];
#                   }
#                 },
#                 error: function(xhr, ajaxOptions, thrownError) {
#                   alert(thrownError + "\r\n" + xhr.statusText + "\r\n" + xhr.responseText);
#                 }
#               });
#             }
#   </script>
#   <script type="text/javascript">
#    $(window).load(function(){
#       var css_tpl = '<style type="text/css">';
#       css_tpl += '#megamenu_173530379 ul.megamenu > li > .sub-menu > .content {';
#       css_tpl += '-webkit-transition: all 500ms ease-out !important;';
#       css_tpl += '-moz-transition: all 500ms ease-out !important;';
#       css_tpl += '-o-transition: all 500ms ease-out !important;';
#       css_tpl += '-ms-transition: all 500ms ease-out !important;';
#       css_tpl += 'transition: all 500ms ease-out !important;';
#       css_tpl += '}</style>'
#     $("head").append(css_tpl);
#   });
#   </script>
#   <script type="text/javascript">
#    $(window).load(function(){
#       var css_tpl = '<style type="text/css">';
#       css_tpl += '#megamenu_80505285 ul.megamenu > li > .sub-menu > .content {';
#       css_tpl += '-webkit-transition: all 200ms ease-out !important;';
#       css_tpl += '-moz-transition: all 200ms ease-out !important;';
#       css_tpl += '-o-transition: all 200ms ease-out !important;';
#       css_tpl += '-ms-transition: all 200ms ease-out !important;';
#       css_tpl += 'transition: all 200ms ease-out !important;';
#       css_tpl += '}</style>'
#     $("head").append(css_tpl);
#   });
#   </script>
#   <script type="text/javascript">
#    $( document ).ready(function() {
# if(document.getElementById("tab-description") != null){
# var opis = document.getElementById("tab-description").textContent;
# var opis = opis.split(",").join("</br><i class='fa fa-check-square-o' aria-hidden='true'></i>");
# document.getElementById("tab-description").innerHTML = opis;
#
# }
# else{
#
# }
# });
#   </script>
#   <script type="text/javascript">
#    function alternate(id){
#   if(document.getElementsByTagName){
#     var table = document.getElementById("tab-description").textContent;
#     var rows = table.getElementsByTagName("<br>");
#     for(i = 0; i < rows.length; i++){
#   //manipulate rows
#       if(i % 2 == 0){
#         rows[i].className = "even";
#       }else{
#         rows[i].className = "odd";
#       }
#     }
#   }
# }
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
#   var camera_slider = $("#camera_wrap_21");
#
#   camera_slider.owlCarousel({
#   	  slideSpeed : 300,
#   	  lazyLoad : true,
#       singleItem: true,
#       autoPlay: true,
#       stopOnHover: true,
#             navigation: true,
#       navigationText: false
#    });
# });
#   </script>
#   <script type="text/javascript">
#    $('.flexslider').flexslider({
# 		animation: "slide",
# 		easing: "easeInBounce",
# 		slideshowSpeed: 3000,
# 		animationSpeed: 500,
#         animationLoop: 1,
# 		pauseOnAction: true,
# 		pauseOnHover: 1,
# 		touch: 0,
# 		controlNav: 1,
# 		directionNav: 1,
# 		maxItems: 4,
#         itemWidth: 245,
#         itemMargin: 10,
#         pausePlay: false
# });
#   </script>
#   <script type="text/javascript">
#    $('#tab46850440 a').click(function (e) {
#   e.preventDefault();
#   $(this).tab('show');
# })
#   </script>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 	function Unsubscribe() {
# 		$.post('https://setec.mk/index.php?route=extension/module/newsletter/unsubscribe',
# 			{
# 				email: $('#newsletter33974985 .email').val()
# 			}, function (e) {
# 				$('#newsletter33974985 .email').val('');
# 				alert(e.message);
# 			}
# 		, 'json');
# 	}
#
# 	function Subscribe() {
# 				if($('input[name="agree_rodo2"]').is(':checked')) {
# 				$.post('https://setec.mk/index.php?route=extension/module/newsletter/subscribe',
# 			{
# 				email: $('#newsletter33974985 .email').val()
# 			}, function (e) {
# 				if(e.error === 1) {
# 					var r = confirm(e.message);
# 					if (r == true) {
# 					    $.post('https://setec.mk/index.php?route=extension/module/newsletter/unsubscribe', {
# 					    	email: $('#newsletter33974985 .email').val()
# 					    }, function (e) {
# 					    	$('#newsletter33974985 .email').val('');
# 					    	alert(e.message);
# 					    }, 'json');
# 					}
# 				} else {
# 					$('#newsletter33974985 .email').val('');
# 					alert(e.message);
# 				}
# 			}
# 		, 'json');
# 				} else {
# 			$('#agree_rodo_form2 .submit').click();
# 		}
# 			}
#
# 	$('#newsletter33974985 .subscribe').click(Subscribe);
# 	$('#newsletter33974985 .unsubscribe').click(Unsubscribe);
# 	$('#newsletter33974985 .email').keypress(function (e) {
# 	    if (e.which == 13) {
# 	        Subscribe();
# 	    }
# 	});
# });
#   </script>
#   <script type="text/javascript">
#    // ===== Scroll to Top ====
# $(window).scroll(function() {
#     if ($(this).scrollTop() >= 50) {        // If page is scrolled more than 50px
#         $('#return-to-top').fadeIn(200);    // Fade in the arrow
#     } else {
#         $('#return-to-top').fadeOut(200);   // Else fade out the arrow
#     }
# });
# $('#return-to-top').click(function() {      // When arrow is clicked
#     $('body,html').animate({
#         scrollTop : 0                       // Scroll to top of body
#     }, 800);
# });
#   </script>
#   <script type="text/javascript">
#    //<![CDATA[
# $(window).load(function(){
# var x = Math.floor((Math.random() * 7) + 1);
# //document.getElementById("demo").innerHTML = x;
# $(function () {
# 	var x = Math.floor((Math.random() * 7) + 1);
# 		$(".filter-product .filter-tabs ul li:nth-child(1)").removeClass('active');
#         $(".filter-product .filter-tabs ul li:nth-child("+x+")").addClass("active");
# 		$(".tab-content.clearfix .tab-pane:nth-child(1)").removeClass('active');
# 		$(".tab-content.clearfix .tab-pane:nth-child("+x+")").addClass("active");
#     })
#     });//]]>
#   </script>
#   <script type="text/javascript">
#    var nitro_xhr;
# if (window.XMLHttpRequest){nitro_xhr=new XMLHttpRequest();}
# else{nitro_xhr=new ActiveXObject("Microsoft.XMLHTTP");}
# nitro_xhr.onreadystatechange=function(){if (nitro_xhr.readyState==4 && nitro_xhr.status==200){var nitroBarWrapper = document.createElement('div'); nitroBarWrapper.innerHTML = nitro_xhr.responseText; document.body.appendChild(nitroBarWrapper);}}
# nitro_xhr.open("GET","index.php?route=extension/module/nitro/getwidget&cachefile=MS0wMGYyNzliYTNiYWFlNmQ0MjI4NGI4MTFiN2ViODdjYi5odG1s&render_time=1.0431640148163",true);
# nitro_xhr.setRequestHeader("X-Requested-With", "XMLHttpRequest");
# nitro_xhr.send();
#   </script>
#  </body>
# </html>

# %% [markdown]
# * class selector - starts with '.' and continues with the name of the class
# (example '.sale')
#
# * id selector - starts with '#' and continues with the name of the id (example '#id')
#
# * tag names - example 'p': paragraph, 'a': anchor (link), 'div' - division

# %%
discounts = soup.select(".sale")  # get every element that has the class 'sale'

# %%
soup.select_one(".sale")  # get the first element that has the class 'sale'
# Out:
# <div class="sale">-45%</div>

# %%
soup.select("p")  # select all paragraphs
# Out:
# [<p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p><a href="http://midea.mk/?page_id=3425" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа VRF системи</b></a></p>,
#  <p><a href="http://midea.mk/?page_id=8105">Внатрешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=7082">Надворешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа топлински пумпи </b></a></p>,
#  <p><a href="http://midea.mk/?page_id=3431">Моноблок топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=5050">Сплит топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа Чилери</b></a></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p> <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank"> <img alt="Club_Card" src="image/catalog/market/Card.png"/>Клуб Картичка</a> </p>,
#  <p> <a class="stat2" href="index.php?route=information/information&amp;information_id=13" style="color:white;"> <img alt="Icon_money" src="image/catalog/market/icon-money.png"/>Кредитирање</a> </p>,
#  <p> <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/outlet-stamp.png"/>Оутлет Производи</a> </p>,
#  <p> <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=73" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png"/>Испорака</a> </p>,
#  <p> <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank"> <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png"/>Вредносен Ваучер</a> </p>,
#  <p><strong id="total_price_ajax"><span id="total_price">0 Ден.</span></strong></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p><a href="http://midea.mk/?page_id=3425" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа VRF системи</b></a></p>,
#  <p><a href="http://midea.mk/?page_id=8105">Внатрешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=7082">Надворешни единици за VRF системи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа топлински пумпи </b></a></p>,
#  <p><a href="http://midea.mk/?page_id=3431">Моноблок топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=5050">Сплит топлински пумпи</a></p>,
#  <p><a href="http://midea.mk/?page_id=3409" style="border-bottom: 1px solid #e5e5e5;"><b>Мидеа Чилери</b></a></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="arrow"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p class="close-menu"></p>,
#  <p class="open-menu"></p>,
#  <p> <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank"> <img alt="Club_Card" src="image/catalog/market/Card.png"/>Клуб Картичка</a> </p>,
#  <p> <a class="stat2" href="index.php?route=information/information&amp;information_id=13" style="color:white;"> <img alt="Icon_money" src="image/catalog/market/icon-money.png"/>Кредитирање</a> </p>,
#  <p> <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/outlet-stamp.png"/>Оутлет Производи</a> </p>,
#  <p> <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=73" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png"/>Испорака</a> </p>,
#  <p> <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank"> <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png"/>Вредносен Ваучер</a> </p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p style="clear: both; text-align: center; margin: 2px !important;"></p>,
#  <p>Претплатете се на билтенот<br/>и добијте попуст</p>]

# %%
soup.find_all("a", {"target": "_blank"})  # find all links having the attribute target witha value of _blank (target='_blank')
# Out:
# [<a class="clearfix" href="http://midea.mk/" target="_blank"><span><strong>Професионална Климатизација</strong></span></a>,
#  <a href="http://midea.mk/" target="_blank"><img src="https://setec.mk/image/catalog/Meni/Midea-Chilers.jpg"/></a>,
#  <a href="https://setec.mk/index.php?route=product/search&amp;search=FIELDMANN" target="_blank"><img src="https://setec.mk/image/catalog/Meni/FIELDMANN_29x292.jpg"/></a>,
#  <a class="clearfix" href="" target="_blank"><span><strong>Оптички Уреди</strong></span></a>,
#  <a class="clearfix" href="https://cc.st.mk/Account/SignIn.aspx" target="_blank"><span><strong>Cashback проверка</strong></span></a>,
#  <a class="clearfix" href="index.php?route=information/information&amp;information_id=15" target="_blank"><span><strong>Кариера</strong></span></a>,
#  <a class="clearfix" href="index.php?route=information/contact" target="_blank"><span><strong><img alt="" src="https://setec.mk/image/catalog/stationery2/icon-phone.png"/>Онлајн нарачка 02 30 80 899</strong></span></a>,
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank"> <img alt="Club_Card" src="image/catalog/market/Card.png"/>Клуб Картичка</a>,
#  <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/outlet-stamp.png"/>Оутлет Производи</a>,
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=73" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png"/>Испорака</a>,
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank"> <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png"/>Вредносен Ваучер</a>,
#  <a class="clearfix" href="http://midea.mk/" target="_blank"><span><strong>Професионална Климатизација</strong></span></a>,
#  <a href="http://midea.mk/" target="_blank"><img src="https://setec.mk/image/catalog/Meni/Midea-Chilers.jpg"/></a>,
#  <a href="https://setec.mk/index.php?route=product/search&amp;search=FIELDMANN" target="_blank"><img src="https://setec.mk/image/catalog/Meni/FIELDMANN_29x292.jpg"/></a>,
#  <a class="clearfix" href="" target="_blank"><span><strong>Оптички Уреди</strong></span></a>,
#  <a class="clearfix" href="https://cc.st.mk/Account/SignIn.aspx" target="_blank"><span><strong>Cashback проверка</strong></span></a>,
#  <a class="clearfix" href="index.php?route=information/information&amp;information_id=15" target="_blank"><span><strong>Кариера</strong></span></a>,
#  <a class="clearfix" href="index.php?route=information/contact" target="_blank"><span><strong><img alt="" src="https://setec.mk/image/catalog/stationery2/icon-phone.png"/>Онлајн нарачка 02 30 80 899</strong></span></a>,
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=133" style="color:white;" target="_blank"> <img alt="Club_Card" src="image/catalog/market/Card.png"/>Клуб Картичка</a>,
#  <a class="stat2" href="http://outlet.setec.mk/" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/outlet-stamp.png"/>Оутлет Производи</a>,
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=73" style="color:white;" target="_blank"> <img alt="free-shipping" src="image/catalog/market/icon-free-shipping.png"/>Испорака</a>,
#  <a class="stat2" href="https://setec.mk/index.php?route=information/information&amp;information_id=398" style="color:white;" target="_blank"> <img alt="Vrednosen_vaucer" src="image/catalog/market/Vrednosen_vaucer.png"/>Вредносен Ваучер</a>,
#  <a href="https://setec.mk/index.php?route=information/information&amp;information_id=528" target="_blank"><img alt="SD_web_slider" src="https://setec.mk/image/cache/catalog/Slider/1140x450_SD_oct_2023-1140x450.jpg"/></a>,
#  <a href="https://setec.mk/index.php?route=information%2Finformation&amp;information_id=527&amp;utm_source=Samsung+Nation+promo+mob&amp;utm_medium=Samsung+Nation+promo+mob&amp;utm_campaign=Samsung+Nation+promo+mob&amp;utm_id=Samsung+Nation+promo+mob&amp;utm_term=Sa" target="_blank"><img alt="Smasung Mob national promo" src="https://setec.mk/image/cache/catalog/Slider/Fall%202023%20%20National%20promotion_1140x450-1140x450.jpg"/></a>,
#  <a href="/index.php?route=information/information&amp;information_id=3" target="_blank"><b>Општите услови и правила</b></a>,
#  <a href="/index.php?route=information/information&amp;information_id=14" target="_blank"><b>Политика на приватност</b></a>]

# %%
regular_price = soup.select(".price-old-new")  # select all elements having the class .price-old-new

# %%
regular_price
# Out:
# [<span class="price-old-new">39,999 Ден.</span>,
#  <span class="price-old-new">49,999 Ден.</span>,
#  <span class="price-old-new">40,999 Ден.</span>,
#  <span class="price-old-new">45,999 Ден.</span>,
#  <span class="price-old-new">159,999 Ден.</span>,
#  <span class="price-old-new">64,999 Ден.</span>,
#  <span class="price-old-new">74,999 Ден.</span>,
#  <span class="price-old-new">27,999 Ден.</span>,
#  <span class="price-old-new">39,999 Ден.</span>,
#  <span class="price-old-new">43,999 Ден.</span>,
#  <span class="price-old-new">28,999 Ден.</span>,
#  <span class="price-old-new">19,999 Ден.</span>,
#  <span class="price-old-new">28,999 Ден.</span>,
#  <span class="price-old-new">42,999 Ден.</span>,
#  <span class="price-old-new">27,999 Ден.</span>,
#  <span class="price-old-new">28,999 Ден.</span>,
#  <span class="price-old-new">10,999 Ден.</span>,
#  <span class="price-old-new">11,999 Ден.</span>,
#  <span class="price-old-new">4,999 Ден.</span>,
#  <span class="price-old-new">12,999 Ден.</span>,
#  <span class="price-old-new">104,490 Ден.</span>,
#  <span class="price-old-new">82,290 Ден.</span>,
#  <span class="price-old-new">42,999 Ден.</span>,
#  <span class="price-old-new">56,999 Ден.</span>,
#  <span class="price-old-new">25,999 Ден.</span>,
#  <span class="price-old-new">25,999 Ден.</span>,
#  <span class="price-old-new">21,999 Ден.</span>,
#  <span class="price-old-new">11,499 Ден.</span>,
#  <span class="price-old-new">6,999 Ден.</span>,
#  <span class="price-old-new">11,999 Ден.</span>,
#  <span class="price-old-new">6,999 Ден.</span>,
#  <span class="price-old-new">1,899 Ден.</span>,
#  <span class="price-old-new">2,199 Ден.</span>,
#  <span class="price-old-new">4,299 Ден.</span>,
#  <span class="price-old-new">4,599 Ден.</span>,
#  <span class="price-old-new">21,999 Ден.</span>,
#  <span class="price-old-new">24,999 Ден.</span>,
#  <span class="price-old-new">26,999 Ден.</span>,
#  <span class="price-old-new">25,999 Ден.</span>,
#  <span class="price-old-new">31,999 Ден.</span>,
#  <span class="price-old-new">35,999 Ден.</span>,
#  <span class="price-old-new">39,999 Ден.</span>,
#  <span class="price-old-new">43,999 Ден.</span>,
#  <span class="price-old-new">43,999 Ден.</span>,
#  <span class="price-old-new">49,999 Ден.</span>,
#  <span class="price-old-new">18,999 Ден.</span>,
#  <span class="price-old-new">33,999 Ден.</span>,
#  <span class="price-old-new">44,999 Ден.</span>,
#  <span class="price-old-new">11,999 Ден.</span>,
#  <span class="price-old-new">12,999 Ден.</span>,
#  <span class="price-old-new">9,999 Ден.</span>,
#  <span class="price-old-new">7,799 Ден.</span>,
#  <span class="price-old-new">38,999 Ден.</span>,
#  <span class="price-old-new">7,499 Ден.</span>,
#  <span class="price-old-new">15,499 Ден.</span>,
#  <span class="price-old-new">20,999 Ден.</span>,
#  <span class="price-old-new">21,999 Ден.</span>,
#  <span class="price-old-new">23,999 Ден.</span>,
#  <span class="price-old-new">24,999 Ден.</span>,
#  <span class="price-old-new">26,999 Ден.</span>,
#  <span class="price-old-new">23,999 Ден.</span>,
#  <span class="price-old-new">29,999 Ден.</span>,
#  <span class="price-old-new">19,999 Ден.</span>,
#  <span class="price-old-new">22,999 Ден.</span>,
#  <span class="price-old-new">6,999 Ден.</span>,
#  <span class="price-old-new">9,999 Ден.</span>,
#  <span class="price-old-new">9,999 Ден.</span>,
#  <span class="price-old-new">24,999 Ден.</span>,
#  <span class="price-old-new">15,999 Ден.</span>,
#  <span class="price-old-new">3,499 Ден.</span>,
#  <span class="price-old-new">4,899 Ден.</span>,
#  <span class="price-old-new">11,499 Ден.</span>,
#  <span class="price-old-new">18,999 Ден.</span>,
#  <span class="price-old-new">12,999 Ден.</span>,
#  <span class="price-old-new">48,999 Ден.</span>,
#  <span class="price-old-new">32,999 Ден.</span>,
#  <span class="price-old-new">35,999 Ден.</span>,
#  <span class="price-old-new">14,999 Ден.</span>,
#  <span class="price-old-new">6,999 Ден.</span>,
#  <span class="price-old-new">27,999 Ден.</span>,
#  <span class="price-old-new">15,999 Ден.</span>,
#  <span class="price-old-new">10,999 Ден.</span>,
#  <span class="price-old-new">4,399 Ден.</span>,
#  <span class="price-old-new">42,599 Ден.</span>,
#  <span class="price-old-new">10,999 Ден.</span>,
#  <span class="price-old-new">2,399 Ден.</span>,
#  <span class="price-old-new">1,299 Ден.</span>,
#  <span class="price-old-new">2,199 Ден.</span>,
#  <span class="price-old-new">3,799 Ден.</span>,
#  <span class="price-old-new">2,599 Ден.</span>,
#  <span class="price-old-new">2,099 Ден.</span>,
#  <span class="price-old-new">2,699 Ден.</span>,
#  <span class="price-old-new">1,999 Ден.</span>,
#  <span class="price-old-new">4,799 Ден.</span>,
#  <span class="price-old-new">24,129 Ден.</span>,
#  <span class="price-old-new">1,369 Ден.</span>,
#  <span class="price-old-new">3,709 Ден.</span>,
#  <span class="price-old-new">1,099 Ден.</span>,
#  <span class="price-old-new">1,399 Ден.</span>,
#  <span class="price-old-new">3,999 Ден.</span>,
#  <span class="price-old-new">1,099 Ден.</span>,
#  <span class="price-old-new">4,399 Ден.</span>,
#  <span class="price-old-new">4,399 Ден.</span>,
#  <span class="price-old-new">1,899 Ден.</span>,
#  <span class="price-old-new">5,199 Ден.</span>,
#  <span class="price-old-new">14,999 Ден.</span>,
#  <span class="price-old-new">49,999 Ден.</span>,
#  <span class="price-old-new">11,999 Ден.</span>,
#  <span class="price-old-new">1,999 Ден.</span>,
#  <span class="price-old-new">3,799 Ден.</span>]

# %%
len(discounts)  # check the length of the list
# Out:
# 110

# %%
len(regular_price)
# Out:
# 110

# %%
products = soup.select(".product")  # select all elements having the class 'product'

# %%
product = products[0]

# %%
discount = product.select_one(".sale")  # select the first element having the class 'sale'

# %%
discount.text
# Out:
# '-45%'

# %%
product.select_one("a").get("href")  # find the first anchor element and get the value of it's "href" attrbute
# Out:
# 'https://setec.mk/index.php?route=product/product&product_id=75937'

# %% [markdown]
# Defining a dictionary of lists for creating a pandas dataframe.
#
# When you have multiple lists that need to contain values connected to some object, (if we do not have a class for this) it's a good practice to create a dictionary with keys as the lists names, and the lists as values.

# %%
prod_dict = {
    "discounts": [],
    "regular_prices": [],
    "names": [],
    "links": [],
}

# %%
prod_dict
# Out:
# {'discounts': [], 'regular_prices': [], 'names': [], 'links': []}

# %%
for product in products:
  discount = product.select_one(".sale")
  if discount:
    discount = discount.text
  else:
    discount = ""

  prod_dict['discounts'].append(discount)  # we access the value of an entry in the dictionary by providing the key in angle brackets

  regular_price = product.select_one(".price-old-new")
  if regular_price:
    regular_price = regular_price.text
  else:
    regular_price = ""

  prod_dict['regular_prices'].append(regular_price)

  name = product.select_one(".name").text
  prod_dict['names'].append(name)
  link = product.select_one("a").get("href")
  prod_dict['links'].append(link)

# %%
prod_dict
# Out:
# {'discounts': ['-45%',
#   '-30%',
#   '-37%',
#   '-21%',
#   '-31%',
#   '-28%',
#   '-45%',
#   '-43%',
#   '-18%',
#   '-32%',
#   '-28%',
#   '-25%',
#   '-28%',
#   '-42%',
#   '-36%',
#   '-47%',
#   '-45%',
#   '-25%',
#   '-24%',
#   '-27%',
#   '-23%',
#   '-22%',
#   '-19%',
#   '-12%',
#   '-23%',
#   '-31%',
#   '-18%',
#   '-39%',
#   '-24%',
#   '-25%',
#   '-26%',
#   '-32%',
#   '-18%',
#   '-30%',
#   '-41%',
#   '',
#   '-23%',
#   '-28%',
#   '-15%',
#   '-10%',
#   '-16%',
#   '-17%',
#   '-13%',
#   '-16%',
#   '-16%',
#   '-18%',
#   '-16%',
#   '-12%',
#   '-11%',
#   '-33%',
#   '-31%',
#   '-30%',
#   '-17%',
#   '-23%',
#   '-17%',
#   '-29%',
#   '-29%',
#   '-14%',
#   '-21%',
#   '-20%',
#   '-26%',
#   '-21%',
#   '-17%',
#   '-35%',
#   '-43%',
#   '-36%',
#   '-30%',
#   '-20%',
#   '-16%',
#   '-25%',
#   '-29%',
#   '-37%',
#   '-13%',
#   '-18%',
#   '-23%',
#   '-29%',
#   '-27%',
#   '-19%',
#   '-40%',
#   '-29%',
#   '-25%',
#   '-25%',
#   '-32%',
#   '-41%',
#   '-30%',
#   '-30%',
#   '-33%',
#   '-31%',
#   '-41%',
#   '-35%',
#   '-35%',
#   '-35%',
#   '-35%',
#   '-60%',
#   '-63%',
#   '-42%',
#   '-34%',
#   '-38%',
#   '-41%',
#   '-54%',
#   '-53%',
#   '-50%',
#   '-45%',
#   '-43%',
#   '-53%',
#   '-33%',
#   '-33%',
#   '-48%',
#   '-21%',
#   '-45%',
#   '-39%'],
#  'regular_prices': ['39,999 Ден.',
#   '49,999 Ден.',
#   '40,999 Ден.',
#   '45,999 Ден.',
#   '159,999 Ден.',
#   '64,999 Ден.',
#   '74,999 Ден.',
#   '27,999 Ден.',
#   '39,999 Ден.',
#   '43,999 Ден.',
#   '28,999 Ден.',
#   '19,999 Ден.',
#   '28,999 Ден.',
#   '42,999 Ден.',
#   '27,999 Ден.',
#   '28,999 Ден.',
#   '10,999 Ден.',
#   '11,999 Ден.',
#   '4,999 Ден.',
#   '12,999 Ден.',
#   '104,490 Ден.',
#   '82,290 Ден.',
#   '42,999 Ден.',
#   '56,999 Ден.',
#   '25,999 Ден.',
#   '25,999 Ден.',
#   '21,999 Ден.',
#   '11,499 Ден.',
#   '6,999 Ден.',
#   '11,999 Ден.',
#   '6,999 Ден.',
#   '1,899 Ден.',
#   '2,199 Ден.',
#   '4,299 Ден.',
#   '4,599 Ден.',
#   '',
#   '21,999 Ден.',
#   '24,999 Ден.',
#   '26,999 Ден.',
#   '25,999 Ден.',
#   '31,999 Ден.',
#   '35,999 Ден.',
#   '39,999 Ден.',
#   '43,999 Ден.',
#   '43,999 Ден.',
#   '49,999 Ден.',
#   '18,999 Ден.',
#   '33,999 Ден.',
#   '44,999 Ден.',
#   '11,999 Ден.',
#   '12,999 Ден.',
#   '9,999 Ден.',
#   '7,799 Ден.',
#   '38,999 Ден.',
#   '7,499 Ден.',
#   '15,499 Ден.',
#   '20,999 Ден.',
#   '21,999 Ден.',
#   '23,999 Ден.',
#   '24,999 Ден.',
#   '26,999 Ден.',
#   '23,999 Ден.',
#   '29,999 Ден.',
#   '19,999 Ден.',
#   '22,999 Ден.',
#   '6,999 Ден.',
#   '9,999 Ден.',
#   '9,999 Ден.',
#   '24,999 Ден.',
#   '15,999 Ден.',
#   '3,499 Ден.',
#   '4,899 Ден.',
#   '11,499 Ден.',
#   '18,999 Ден.',
#   '12,999 Ден.',
#   '48,999 Ден.',
#   '32,999 Ден.',
#   '35,999 Ден.',
#   '14,999 Ден.',
#   '6,999 Ден.',
#   '27,999 Ден.',
#   '15,999 Ден.',
#   '10,999 Ден.',
#   '4,399 Ден.',
#   '42,599 Ден.',
#   '10,999 Ден.',
#   '2,399 Ден.',
#   '1,299 Ден.',
#   '2,199 Ден.',
#   '3,799 Ден.',
#   '2,599 Ден.',
#   '2,099 Ден.',
#   '2,699 Ден.',
#   '1,999 Ден.',
#   '4,799 Ден.',
#   '24,129 Ден.',
#   '1,369 Ден.',
#   '3,709 Ден.',
#   '1,099 Ден.',
#   '1,399 Ден.',
#   '3,999 Ден.',
#   '1,099 Ден.',
#   '4,399 Ден.',
#   '4,399 Ден.',
#   '1,899 Ден.',
#   '5,199 Ден.',
#   '14,999 Ден.',
#   '49,999 Ден.',
#   '11,999 Ден.',
#   '1,999 Ден.',
#   '3,799 Ден.'],
#  'names': [' TCL 58P635 ',
#   ' SAMSUNG UE55CU8072UXXH ',
#   ' SAMSUNG UE55AU7092UXXH ',
#   ' SAMSUNG UE65AU7092UXXH ',
#   ' SONY XR65A75KAEP ',
#   ' SONY KD55X80JCEP ',
#   ' TCL 65C735 ',
#   ' TCL 43P635 ',
#   ' PHILIPS 65PUS7008 ',
#   ' PHILIPS 55PUS8118 ',
#   ' Hisense 55A63H ',
#   ' Hisense 43A6BG ',
#   ' Hisense 55A6BG ',
#   ' TELEFUNKEN 65UA9005 ',
#   ' TELEFUNKEN 50UA9005 ',
#   ' ST-55BX7800 ',
#   ' ST-32BH5800 ',
#   ' TCL TS7010 ',
#   ' PowerBox SM2126 ',
#   ' Samsung SM-A145 Galaxy A14 4 / 64 Green ',
#   ' Apple iPhone 14 Pro Max 128GB Deep Purple ',
#   ' Apple iPhone 14 Plus 128GB Midnight ',
#   ' Apple iPhone 11 - 128GB Black ',
#   ' Samsung Galaxy S23 5G Cream 8 / 128 ',
#   ' Samsung SM-A346 Galaxy A34 Lime 5G 6 / 128 ',
#   ' Samsung SM-R920 Galaxy Watch 5 PRO Black 45 mm ',
#   ' Xiaomi Redmi Note 12 PRO 8 / 256GB Graphite Gray ',
#   ' Xiaomi Redmi 10 2022 4 / 64GB Blue ',
#   ' Xiaomi Redmi A2+ 3 / 64GB Black ',
#   ' Xiaomi POCO M4 5G 6 / 128GB Black ',
#   ' Motorola Moto E13 Cosmic Black 2 / 64 ',
#   ' XIAOMI Redmi Buds 4 Lite Black ',
#   ' Xiaomi Redmi Power Bank 3 20.000mAh fast charge 18W ',
#   ' Mibro Watch Lite Black ',
#   ' Xiaomi Kieslect Smart Calling Watch Kr Black ',
#   ' Power Box K20 Earbuds black ',
#   ' ASUS X515EA-BQ312 (Slate Grey) ',
#   ' ACER Aspire 3 A315-24P ',
#   ' HP 250 G8 (Dark Ash Silver) ',
#   ' LENOVO IdeaPad 1 15AMN7 ( GRAY ) ',
#   ' ASUS X515EA-BQ522 ( Slate Grey ) ',
#   ' ASUS X1502ZA-BQ511 ( Quiet Blue ) ',
#   ' LENOVO IdeaPad 3 15ABR8 ( GRAY ) ',
#   ' Lenovo IdeaPad 3 15IAU7 ( GRAY ) ',
#   ' LENOVO GAMING 15IHU6 (Black) ',
#   ' ASUS TUF FX506HC-HN111 ',
#   ' Конфигурација INTEL GAMER GALAXY+  ',
#   ' Конфигурација AMD PRO  ',
#   ' Конфигурација INTEL GAMER LEGION  ',
#   ' Philips FullHD USB-C monitor 24E1N3300A ',
#   ' Philips FullHD Curved LCD Монитор 322E1C ',
#   ' GAMING Столица CRAZY SPARTAN ',
#   ' Lenovo TAB M8 (TB300FU) ',
#   ' Sony PlayStation 5 Disc Edition Console ',
#   ' HP LaserJet MFP M141w ',
#   ' ST WM 7100MWE XXL ',
#   ' INDESIT EWC 81483 ',
#   ' SAMSUNG WW71T301MWW / LE ',
#   ' CANDY RO 1484DWMT / 1-S ',
#   ' Gorenje WNHPI84AS ',
#   ' ST WDI106148TWD ',
#   ' CANDY ZEROWATT ETDE H8A1DE-S ',
#   ' CANDY ROE H10A2TCEX-S ',
#   ' MIDEA WQP12-5201-DW ',
#   ' MIDEA MID60S110.1-MK ',
#   ' ST BHV-3275G ',
#   ' ST BHV-6475G ',
#   ' ST BOM-6FM76X ',
#   ' CANDY PCT25CBCH64CCB ',
#   ' Electrolux EOH3H00BX ',
#   ' ST F6X 60 2 Motors ',
#   ' ST MWO 20WJ ',
#   ' ST ESH60WHK Superior Technology ',
#   ' ST EVK6450XF Superior Technology ',
#   ' ST RF-263WH ',
#   ' MIDEA MDRF632FIE46 ',
#   ' MIDEA MDRB424FGF02 ',
#   ' SAMSUNG RB34T602FSA / EK ',
#   ' MIDEA MDRC207SLF01G ',
#   ' ST WH80ZMK2 ',
#   ' Electrolux EW6FN428BC ',
#   ' Hisense FC184D4AW1 ',
#   ' Philips FC9351 / 01 ',
#   ' Philips DST5010 / 10 ',
#   ' Philips EP2231 / 40 ',
#   ' Philips HD9252 / 90 ',
#   ' Philips HR3705 / 00 ',
#   ' Philips AWP2936BLT / 10 ',
#   ' Philips HC3510 / 15 ',
#   ' Philips S1232 / 41 ',
#   ' Philips BRE224 / 00 ',
#   ' Philips BHD341 / 10 ',
#   ' Philips BHS376 / 00 ',
#   ' ST E825EI Superior Technology ',
#   ' Rowenta TN604MF0 ',
#   ' Rowenta GZ3039WO ',
#   ' Rowenta SF161LF0 ',
#   ' Tefal HB533138 ',
#   ' Tefal PP1330V0 ',
#   ' ST HD-O2400BP ',
#   ' ST DF-2000WWI ',
#   ' ST MTG-800WA ',
#   ' ST J800XJ ',
#   ' ST VCC-1601HWT ',
#   ' ST SI-2600BPK ',
#   ' ARIETE STEAM MOP 10 IN 1 ',
#   ' XIAOMI Mi Robot Vacuum E10 ',
#   ' Midea Breezeless E CB1-12HRFN8-I / CB1-12HFNX-O ',
#   ' ST FOREST PLUS ',
#   ' ST AH-281C ',
#   ' ST PN-2500 '],
#  'links': ['https://setec.mk/index.php?route=product/product&product_id=75937',
#   'https://setec.mk/index.php?route=product/product&product_id=55773',
#   'https://setec.mk/index.php?route=product/product&product_id=54054',
#   'https://setec.mk/index.php?route=product/product&product_id=54167',
#   'https://setec.mk/index.php?route=product/product&product_id=75843',
#   'https://setec.mk/index.php?route=product/product&product_id=74342',
#   'https://setec.mk/index.php?route=product/product&product_id=75531',
#   'https://setec.mk/index.php?route=product/product&product_id=75980',
#   'https://setec.mk/index.php?route=product/product&product_id=56574',
#   'https://setec.mk/index.php?route=product/product&product_id=56183',
#   'https://setec.mk/index.php?route=product/product&product_id=76521',
#   'https://setec.mk/index.php?route=product/product&product_id=76518',
#   'https://setec.mk/index.php?route=product/product&product_id=76749',
#   'https://setec.mk/index.php?route=product/product&product_id=76283',
#   'https://setec.mk/index.php?route=product/product&product_id=76249',
#   'https://setec.mk/index.php?route=product/product&product_id=55305',
#   'https://setec.mk/index.php?route=product/product&product_id=54486',
#   'https://setec.mk/index.php?route=product/product&product_id=77091',
#   'https://setec.mk/index.php?route=product/product&product_id=33737',
#   'https://setec.mk/index.php?route=product/product&product_id=60823',
#   'https://setec.mk/index.php?route=product/product&product_id=53833',
#   'https://setec.mk/index.php?route=product/product&product_id=54059',
#   'https://setec.mk/index.php?route=product/product&product_id=49301',
#   'https://setec.mk/index.php?route=product/product&product_id=76482',
#   'https://setec.mk/index.php?route=product/product&product_id=55448',
#   'https://setec.mk/index.php?route=product/product&product_id=75888',
#   'https://setec.mk/index.php?route=product/product&product_id=76948',
#   'https://setec.mk/index.php?route=product/product&product_id=77271',
#   'https://setec.mk/index.php?route=product/product&product_id=77245',
#   'https://setec.mk/index.php?route=product/product&product_id=77263',
#   'https://setec.mk/index.php?route=product/product&product_id=77090',
#   'https://setec.mk/index.php?route=product/product&product_id=55633',
#   'https://setec.mk/index.php?route=product/product&product_id=52226',
#   'https://setec.mk/index.php?route=product/product&product_id=56507',
#   'https://setec.mk/index.php?route=product/product&product_id=53918',
#   'https://setec.mk/index.php?route=product/product&product_id=76883',
#   'https://setec.mk/index.php?route=product/product&product_id=53184',
#   'https://setec.mk/index.php?route=product/product&product_id=55786',
#   'https://setec.mk/index.php?route=product/product&product_id=56592',
#   'https://setec.mk/index.php?route=product/product&product_id=56134',
#   'https://setec.mk/index.php?route=product/product&product_id=55011',
#   'https://setec.mk/index.php?route=product/product&product_id=54156',
#   'https://setec.mk/index.php?route=product/product&product_id=55977',
#   'https://setec.mk/index.php?route=product/product&product_id=54984',
#   'https://setec.mk/index.php?route=product/product&product_id=56697',
#   'https://setec.mk/index.php?route=product/product&product_id=55816',
#   'https://setec.mk/index.php?route=product/product&product_id=55392',
#   'https://setec.mk/index.php?route=product/product&product_id=55767',
#   'https://setec.mk/index.php?route=product/product&product_id=56583',
#   'https://setec.mk/index.php?route=product/product&product_id=32803',
#   'https://setec.mk/index.php?route=product/product&product_id=27754',
#   'https://setec.mk/index.php?route=product/product&product_id=20307',
#   'https://setec.mk/index.php?route=product/product&product_id=55228',
#   'https://setec.mk/index.php?route=product/product&product_id=20522',
#   'https://setec.mk/index.php?route=product/product&product_id=32512',
#   'https://setec.mk/index.php?route=product/product&product_id=76287',
#   'https://setec.mk/index.php?route=product/product&product_id=74625',
#   'https://setec.mk/index.php?route=product/product&product_id=77186',
#   'https://setec.mk/index.php?route=product/product&product_id=76852',
#   'https://setec.mk/index.php?route=product/product&product_id=33857',
#   'https://setec.mk/index.php?route=product/product&product_id=77145',
#   'https://setec.mk/index.php?route=product/product&product_id=72955',
#   'https://setec.mk/index.php?route=product/product&product_id=76303',
#   'https://setec.mk/index.php?route=product/product&product_id=73358',
#   'https://setec.mk/index.php?route=product/product&product_id=76220',
#   'https://setec.mk/index.php?route=product/product&product_id=76223',
#   'https://setec.mk/index.php?route=product/product&product_id=76224',
#   'https://setec.mk/index.php?route=product/product&product_id=76405',
#   'https://setec.mk/index.php?route=product/product&product_id=76298',
#   'https://setec.mk/index.php?route=product/product&product_id=77204',
#   'https://setec.mk/index.php?route=product/product&product_id=66256',
#   'https://setec.mk/index.php?route=product/product&product_id=60454',
#   'https://setec.mk/index.php?route=product/product&product_id=70069',
#   'https://setec.mk/index.php?route=product/product&product_id=73028',
#   'https://setec.mk/index.php?route=product/product&product_id=77049',
#   'https://setec.mk/index.php?route=product/product&product_id=77060',
#   'https://setec.mk/index.php?route=product/product&product_id=74087',
#   'https://setec.mk/index.php?route=product/product&product_id=73989',
#   'https://setec.mk/index.php?route=product/product&product_id=76753',
#   'https://setec.mk/index.php?route=product/product&product_id=77212',
#   'https://setec.mk/index.php?route=product/product&product_id=77205',
#   'https://setec.mk/index.php?route=product/product&product_id=77051',
#   'https://setec.mk/index.php?route=product/product&product_id=70669',
#   'https://setec.mk/index.php?route=product/product&product_id=74692',
#   'https://setec.mk/index.php?route=product/product&product_id=72604',
#   'https://setec.mk/index.php?route=product/product&product_id=75262',
#   'https://setec.mk/index.php?route=product/product&product_id=72219',
#   'https://setec.mk/index.php?route=product/product&product_id=33536',
#   'https://setec.mk/index.php?route=product/product&product_id=33457',
#   'https://setec.mk/index.php?route=product/product&product_id=33298',
#   'https://setec.mk/index.php?route=product/product&product_id=72430',
#   'https://setec.mk/index.php?route=product/product&product_id=74324',
#   'https://setec.mk/index.php?route=product/product&product_id=72605',
#   'https://setec.mk/index.php?route=product/product&product_id=33239',
#   'https://setec.mk/index.php?route=product/product&product_id=77292',
#   'https://setec.mk/index.php?route=product/product&product_id=76269',
#   'https://setec.mk/index.php?route=product/product&product_id=75425',
#   'https://setec.mk/index.php?route=product/product&product_id=74129',
#   'https://setec.mk/index.php?route=product/product&product_id=77200',
#   'https://setec.mk/index.php?route=product/product&product_id=70271',
#   'https://setec.mk/index.php?route=product/product&product_id=73472',
#   'https://setec.mk/index.php?route=product/product&product_id=72290',
#   'https://setec.mk/index.php?route=product/product&product_id=71179',
#   'https://setec.mk/index.php?route=product/product&product_id=31976',
#   'https://setec.mk/index.php?route=product/product&product_id=34939',
#   'https://setec.mk/index.php?route=product/product&product_id=75289',
#   'https://setec.mk/index.php?route=product/product&product_id=12490',
#   'https://setec.mk/index.php?route=product/product&product_id=76952',
#   'https://setec.mk/index.php?route=product/product&product_id=60834',
#   'https://setec.mk/index.php?route=product/product&product_id=20626',
#   'https://setec.mk/index.php?route=product/product&product_id=72090']}

# %%
len(prod_dict["discounts"]) == len(prod_dict["regular_prices"]) == len(prod_dict["names"]) == len(prod_dict["links"])  # check if the lengths of all arrays are equal
# Out:
# True

# %%
# we can create a dataframe by passing the dictionary of lists
# the keys will be the column names and each list will represent the values of the column
data = pd.DataFrame(prod_dict)

# %%
data
# Out:
#     discounts regular_prices  \
# 0        -45%    39,999 Ден.
# 1        -30%    49,999 Ден.
# 2        -37%    40,999 Ден.
# 3        -21%    45,999 Ден.
# 4        -31%   159,999 Ден.
# ..        ...            ...
# 106      -33%    14,999 Ден.
# 107      -48%    49,999 Ден.
# 108      -21%    11,999 Ден.
# 109      -45%     1,999 Ден.
# 110      -39%     3,799 Ден.
#
#                                                  names  \
# 0                                          TCL 58P635
# 1                              SAMSUNG UE55CU8072UXXH
# 2                              SAMSUNG UE55AU7092UXXH
# 3                              SAMSUNG UE65AU7092UXXH
# 4                                    SONY XR65A75KAEP
# ..                                                 ...
# 106                        XIAOMI Mi Robot Vacuum E10
# 107   Midea Breezeless E CB1-12HRFN8-I / CB1-12HFNX-O
# 108                                    ST FOREST PLUS
# 109                                        ST AH-281C
# 110                                        ST PN-2500
#
#                                                  links
# 0    https://setec.mk/index.php?route=product/produ...
# 1    https://setec.mk/index.php?route=product/produ...
# 2    https://setec.mk/index.php?route=product/produ...
# 3    https://setec.mk/index.php?route=product/produ...
# 4    https://setec.mk/index.php?route=product/produ...
# ..                                                 ...
# 106  https://setec.mk/index.php?route=product/produ...
# 107  https://setec.mk/index.php?route=product/produ...
# 108  https://setec.mk/index.php?route=product/produ...
# 109  https://setec.mk/index.php?route=product/produ...
# 110  https://setec.mk/index.php?route=product/produ...
#
# [111 rows x 4 columns]

# %%
# save the dataframe as a csv somewhere in Google Drive
data.to_csv("/content/drive/MyDrive/VNP-2023 24 - Milena/Auditoriski/g1/data.csv")
